# %% [markdown]
# # Install needed libraries

# %%
# !pip install tensorflow==2.3.0
# !pip install gym
# !pip install -e . #setup project

#import needed libraries
import gym 
import random
import sys
import numpy as np
import math

#import game environement

import gym_MLAA
env = gym.make('maze-random-5x5-portals-v0')

states = env.observation_space
actions = env.action_space
print(states)
print(actions)
# Out:
# Requirement already satisfied: tensorflow==2.3.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (2.3.0)
# Requirement already satisfied: scipy==1.4.1 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.4.1)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (2.8.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.18.5)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.1.2)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (3.13.0)
# Requirement already satisfied: wrapt>=1.11.1 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.12.1)
# Requirement already satisfied: wheel>=0.26 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (0.36.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.15.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (2.10.0)
# Requirement already satisfied: gast==0.3.3 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (0.3.3)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.34.1)
# Requirement already satisfied: astunparse==1.6.3 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.8 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (2.3.0)
# Requirement already satisfied: absl-py>=0.7.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (0.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (49.2.0.post20200714)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.22.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.3.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.7.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.24.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in /Users/Diego/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2020.6.20)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.1.0)
# Requirement already satisfied: gym in /Users/Diego/anaconda3/lib/python3.8/site-packages (0.21.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from gym) (1.5.0)
# Requirement already satisfied: numpy>=1.18.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from gym) (1.18.5)
# Obtaining file:///Users/Diego/Documents/DATAAI/X-INF581/gym_MLAA
# Requirement already satisfied: gym in /Users/Diego/anaconda3/lib/python3.8/site-packages (from gym-MLAA==0.1) (0.21.0)
# Requirement already satisfied: pygame in /Users/Diego/anaconda3/lib/python3.8/site-packages (from gym-MLAA==0.1) (2.1.2)
# Requirement already satisfied: numpy in /Users/Diego/anaconda3/lib/python3.8/site-packages (from gym-MLAA==0.1) (1.18.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/Diego/anaconda3/lib/python3.8/site-packages (from gym->gym-MLAA==0.1) (1.5.0)
# Installing collected packages: gym-MLAA
#   Attempting uninstall: gym-MLAA
#     Found existing installation: gym-MLAA 0.1
#     Uninstalling gym-MLAA-0.1:
#       Successfully uninstalled gym-MLAA-0.1
#   Running setup.py develop for gym-MLAA
# Successfully installed gym-MLAA
# pygame 2.1.2 (SDL 2.0.18, Python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Box([0 0], [4 4], (2,), int64)
# Discrete(4)

# %% [markdown]
# # Setting Env and Training Constants

# %%
'''
Defining the environment related constants
'''
# Number of discrete states (bucket) per state dimension
MAZE_SIZE = tuple((env.observation_space.high + np.ones(env.observation_space.shape)).astype(int))
NUM_BUCKETS = MAZE_SIZE  # one bucket per grid

# Number of discrete actions
NUM_ACTIONS = env.action_space.n  # ["N", "S", "E", "W"]
# Bounds for each discrete state
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))

'''
Learning related constants
'''
MIN_EXPLORE_RATE = 0.001
MIN_LEARNING_RATE = 0.2
DECAY_FACTOR = np.prod(MAZE_SIZE, dtype=float) / 10.0

'''
Defining the simulation related constants
'''
NUM_EPISODES = 50000
MAX_T = np.prod(MAZE_SIZE, dtype=int) * 100
STREAK_TO_END = 100
SOLVED_T = np.prod(MAZE_SIZE, dtype=int)
#DEBUG_MODE = 0
RENDER_MAZE = True
ENABLE_RECORDING = True

'''
Creating a Q-Table for each state-action pair
'''
q_table = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,), dtype=float)

'''
Begin simulation
'''
recording_folder = "/tmp/maze_q_learning"

# %% [markdown]
# # Define Helper Functions

# %%
def select_action(state, explore_rate,q_table):
    # Select a random action
    if random.random() < explore_rate:
        action = env.action_space.sample()
    # Select the action with the highest q
    else:
        action = int(np.argmax(q_table[state]))
    return action


def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))


def get_learning_rate(t):
    return max(MIN_LEARNING_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))


def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

# %%
#different goals
CLOSE_GOAL = np.array((1,1))
MID_GOAL = (np.array(env.maze_view.maze_size)/2).astype(int)
FAR_GOAL = np.array((env.maze_view.maze_size[0]-1,env.maze_view.maze_size[1]-1)) #Far away

#Store all results
Goals = [CLOSE_GOAL,MID_GOAL,FAR_GOAL]

# %% [markdown]
# # Q Learning

# %%
Results = []
for goal in Goals:
    #to store the results for current goal
    Q_timeSteps_list = []
    Q_TotalReward_list = []
    Q_Episodes_list = []
    #restarting the q_table
    q_table = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,), dtype=float)
    #changing goals
    env.maze_view.change_goal(goal)
    # Instantiating the learning related parameters
    learning_rate = get_learning_rate(0)
    explore_rate = get_explore_rate(0)
    discount_factor = 0.99

    num_streaks = 0
    # Render tha maze
    env.render()
    
    for episode in range(NUM_EPISODES):

        # Reset the environment
        obv = env.reset()

        # the initial state
        state_0 = state_to_bucket(obv)
        action = select_action(state_0, explore_rate,q_table)
        total_reward = 0

        for t in range(MAX_T):

            # execute the action
            obv, reward, done, _ = env.step(action)

            # Observe the result
            state = state_to_bucket(obv)
            total_reward += reward

            # Select an action
            action = select_action(state_0, explore_rate,q_table)

            # Update the Q based on the result
            best_q = np.amax(q_table[state])
            q_table[state_0 + (action,)] += learning_rate * (reward + discount_factor * (best_q) - q_table[state_0 + (action,)])
            #q_table[state_0 + (action,)] += learning_rate * (reward + discount_factor * q_table[state_0 + (action,)] - q_table[state_0 + (action,)])

            # Setting up for the next iteration
            state_0 = state

            # Render tha maze
#             if episode==0:
            if RENDER_MAZE:
                env.render()

            if env.is_game_over():
                sys.exit()

            if done:
                print("Episode %d finished after %f time steps with total reward = %f (streak %d)."
                      % (episode, t, total_reward, num_streaks))
                Q_Episodes_list.append(episode)
                Q_timeSteps_list.append(t)
                Q_TotalReward_list.append(total_reward)

                if t <= SOLVED_T:
                    num_streaks += 1
                else:
                    num_streaks = 0
                break

            elif t >= MAX_T - 1:
                print("Episode %d timed out at %d with total reward = %f."
                      % (episode, t, total_reward))

        # It's considered done when it's solved over 120 times consecutively
        if num_streaks > STREAK_TO_END:
            break

        # Update parameters
        explore_rate = get_explore_rate(episode)
        learning_rate = get_learning_rate(episode)
    Results.append(( Q_timeSteps_list,Q_TotalReward_list,Q_Episodes_list ))
# Out:
# Episode 0 finished after 188.000000 time steps with total reward = 0.248000 (streak 0).
# Episode 1 finished after 395.000000 time steps with total reward = -0.580000 (streak 0).
# Episode 2 finished after 108.000000 time steps with total reward = 0.568000 (streak 0).
# Episode 3 finished after 253.000000 time steps with total reward = -0.012000 (streak 0).
# Episode 4 finished after 118.000000 time steps with total reward = 0.528000 (streak 0).
# Episode 5 finished after 117.000000 time steps with total reward = 0.532000 (streak 0).
# Episode 6 finished after 248.000000 time steps with total reward = 0.008000 (streak 0).
# Episode 7 finished after 158.000000 time steps with total reward = 0.368000 (streak 0).
# Episode 8 finished after 177.000000 time steps with total reward = 0.292000 (streak 0).
# Episode 9 finished after 87.000000 time steps with total reward = 0.652000 (streak 0).
# Episode 10 finished after 51.000000 time steps with total reward = 0.796000 (streak 0).
# Episode 11 finished after 125.000000 time steps with total reward = 0.500000 (streak 0).
# Episode 12 finished after 158.000000 time steps with total reward = 0.368000 (streak 0).
# Episode 13 finished after 27.000000 time steps with total reward = 0.892000 (streak 0).
# Episode 14 finished after 24.000000 time steps with total reward = 0.904000 (streak 0).
# Episode 15 finished after 23.000000 time steps with total reward = 0.908000 (streak 1).
# Episode 16 finished after 285.000000 time steps with total reward = -0.140000 (streak 2).
# Episode 17 finished after 13.000000 time steps with total reward = 0.948000 (streak 0).
# Episode 18 finished after 24.000000 time steps with total reward = 0.904000 (streak 1).
# Episode 19 finished after 30.000000 time steps with total reward = 0.880000 (streak 2).
# Episode 20 finished after 87.000000 time steps with total reward = 0.652000 (streak 0).
# Episode 21 finished after 43.000000 time steps with total reward = 0.828000 (streak 0).
# Episode 22 finished after 137.000000 time steps with total reward = 0.452000 (streak 0).
# Episode 23 finished after 29.000000 time steps with total reward = 0.884000 (streak 0).
# Episode 24 finished after 830.000000 time steps with total reward = -2.320000 (streak 0).
# Episode 25 finished after 59.000000 time steps with total reward = 0.764000 (streak 0).
# Episode 26 finished after 62.000000 time steps with total reward = 0.752000 (streak 0).
# Episode 27 finished after 78.000000 time steps with total reward = 0.688000 (streak 0).
# Episode 28 finished after 66.000000 time steps with total reward = 0.736000 (streak 0).
# Episode 29 finished after 75.000000 time steps with total reward = 0.700000 (streak 0).
# Episode 30 finished after 16.000000 time steps with total reward = 0.936000 (streak 0).
# Episode 31 finished after 16.000000 time steps with total reward = 0.936000 (streak 1).
# Episode 32 finished after 16.000000 time steps with total reward = 0.936000 (streak 2).
# Episode 33 finished after 16.000000 time steps with total reward = 0.936000 (streak 3).
# Episode 34 finished after 16.000000 time steps with total reward = 0.936000 (streak 4).
# Episode 35 finished after 16.000000 time steps with total reward = 0.936000 (streak 5).
# Episode 36 finished after 16.000000 time steps with total reward = 0.936000 (streak 6).
# Episode 37 finished after 16.000000 time steps with total reward = 0.936000 (streak 7).
# Episode 38 finished after 16.000000 time steps with total reward = 0.936000 (streak 8).
# Episode 39 finished after 16.000000 time steps with total reward = 0.936000 (streak 9).
# Episode 40 finished after 16.000000 time steps with total reward = 0.936000 (streak 10).
# Episode 41 finished after 16.000000 time steps with total reward = 0.936000 (streak 11).
# Episode 42 finished after 16.000000 time steps with total reward = 0.936000 (streak 12).
# Episode 43 finished after 16.000000 time steps with total reward = 0.936000 (streak 13).
# Episode 44 finished after 16.000000 time steps with total reward = 0.936000 (streak 14).
# Episode 45 finished after 16.000000 time steps with total reward = 0.936000 (streak 15).
# Episode 46 finished after 16.000000 time steps with total reward = 0.936000 (streak 16).
# Episode 47 finished after 16.000000 time steps with total reward = 0.936000 (streak 17).
# Episode 48 finished after 16.000000 time steps with total reward = 0.936000 (streak 18).
# Episode 49 finished after 16.000000 time steps with total reward = 0.936000 (streak 19).
# Episode 50 finished after 16.000000 time steps with total reward = 0.936000 (streak 20).
# Episode 51 finished after 16.000000 time steps with total reward = 0.936000 (streak 21).
# Episode 52 finished after 16.000000 time steps with total reward = 0.936000 (streak 22).
# Episode 53 finished after 16.000000 time steps with total reward = 0.936000 (streak 23).
# Episode 54 finished after 16.000000 time steps with total reward = 0.936000 (streak 24).
# Episode 55 finished after 16.000000 time steps with total reward = 0.936000 (streak 25).
# Episode 56 finished after 16.000000 time steps with total reward = 0.936000 (streak 26).
# Episode 57 finished after 16.000000 time steps with total reward = 0.936000 (streak 27).
# Episode 58 finished after 16.000000 time steps with total reward = 0.936000 (streak 28).
# Episode 59 finished after 16.000000 time steps with total reward = 0.936000 (streak 29).
# Episode 60 finished after 16.000000 time steps with total reward = 0.936000 (streak 30).
# Episode 61 finished after 16.000000 time steps with total reward = 0.936000 (streak 31).
# Episode 62 finished after 16.000000 time steps with total reward = 0.936000 (streak 32).
# Episode 63 finished after 16.000000 time steps with total reward = 0.936000 (streak 33).
# Episode 64 finished after 16.000000 time steps with total reward = 0.936000 (streak 34).
# Episode 65 finished after 16.000000 time steps with total reward = 0.936000 (streak 35).
# Episode 66 finished after 16.000000 time steps with total reward = 0.936000 (streak 36).
# Episode 67 finished after 16.000000 time steps with total reward = 0.936000 (streak 37).
# Episode 68 finished after 16.000000 time steps with total reward = 0.936000 (streak 38).
# Episode 69 finished after 16.000000 time steps with total reward = 0.936000 (streak 39).
# Episode 70 finished after 16.000000 time steps with total reward = 0.936000 (streak 40).
# Episode 71 finished after 16.000000 time steps with total reward = 0.936000 (streak 41).
# Episode 72 finished after 16.000000 time steps with total reward = 0.936000 (streak 42).
# Episode 73 finished after 16.000000 time steps with total reward = 0.936000 (streak 43).
# Episode 74 finished after 16.000000 time steps with total reward = 0.936000 (streak 44).
# Episode 75 finished after 16.000000 time steps with total reward = 0.936000 (streak 45).
# Episode 76 finished after 16.000000 time steps with total reward = 0.936000 (streak 46).
# Episode 77 finished after 16.000000 time steps with total reward = 0.936000 (streak 47).
# Episode 78 finished after 16.000000 time steps with total reward = 0.936000 (streak 48).
# Episode 79 finished after 16.000000 time steps with total reward = 0.936000 (streak 49).
# Episode 80 finished after 16.000000 time steps with total reward = 0.936000 (streak 50).
# Episode 81 finished after 16.000000 time steps with total reward = 0.936000 (streak 51).
# Episode 82 finished after 16.000000 time steps with total reward = 0.936000 (streak 52).
# Episode 83 finished after 16.000000 time steps with total reward = 0.936000 (streak 53).
# Episode 84 finished after 16.000000 time steps with total reward = 0.936000 (streak 54).
# Episode 85 finished after 16.000000 time steps with total reward = 0.936000 (streak 55).
# Episode 86 finished after 16.000000 time steps with total reward = 0.936000 (streak 56).
# Episode 87 finished after 16.000000 time steps with total reward = 0.936000 (streak 57).
# Episode 88 finished after 16.000000 time steps with total reward = 0.936000 (streak 58).
# Episode 89 finished after 16.000000 time steps with total reward = 0.936000 (streak 59).
# Episode 90 finished after 16.000000 time steps with total reward = 0.936000 (streak 60).
# Episode 91 finished after 16.000000 time steps with total reward = 0.936000 (streak 61).
# Episode 92 finished after 16.000000 time steps with total reward = 0.936000 (streak 62).
# Episode 93 finished after 16.000000 time steps with total reward = 0.936000 (streak 63).
# Episode 94 finished after 16.000000 time steps with total reward = 0.936000 (streak 64).
# Episode 95 finished after 16.000000 time steps with total reward = 0.936000 (streak 65).
# Episode 96 finished after 16.000000 time steps with total reward = 0.936000 (streak 66).
# Episode 97 finished after 16.000000 time steps with total reward = 0.936000 (streak 67).
# Episode 98 finished after 16.000000 time steps with total reward = 0.936000 (streak 68).
# Episode 99 finished after 16.000000 time steps with total reward = 0.936000 (streak 69).
# Episode 100 finished after 16.000000 time steps with total reward = 0.936000 (streak 70).
# Episode 101 finished after 16.000000 time steps with total reward = 0.936000 (streak 71).
# Episode 102 finished after 16.000000 time steps with total reward = 0.936000 (streak 72).
# Episode 103 finished after 16.000000 time steps with total reward = 0.936000 (streak 73).
# Episode 104 finished after 16.000000 time steps with total reward = 0.936000 (streak 74).
# Episode 105 finished after 16.000000 time steps with total reward = 0.936000 (streak 75).
# Episode 106 finished after 16.000000 time steps with total reward = 0.936000 (streak 76).
# Episode 107 finished after 16.000000 time steps with total reward = 0.936000 (streak 77).
# Episode 108 finished after 16.000000 time steps with total reward = 0.936000 (streak 78).
# Episode 109 finished after 16.000000 time steps with total reward = 0.936000 (streak 79).
# Episode 110 finished after 16.000000 time steps with total reward = 0.936000 (streak 80).
# Episode 111 finished after 16.000000 time steps with total reward = 0.936000 (streak 81).
# Episode 112 finished after 16.000000 time steps with total reward = 0.936000 (streak 82).
# Episode 113 finished after 16.000000 time steps with total reward = 0.936000 (streak 83).
# Episode 114 finished after 16.000000 time steps with total reward = 0.936000 (streak 84).
# Episode 115 finished after 16.000000 time steps with total reward = 0.936000 (streak 85).
# Episode 116 finished after 16.000000 time steps with total reward = 0.936000 (streak 86).
# Episode 117 finished after 16.000000 time steps with total reward = 0.936000 (streak 87).
# Episode 118 finished after 16.000000 time steps with total reward = 0.936000 (streak 88).
# Episode 119 finished after 16.000000 time steps with total reward = 0.936000 (streak 89).
# Episode 120 finished after 16.000000 time steps with total reward = 0.936000 (streak 90).
# Episode 121 finished after 16.000000 time steps with total reward = 0.936000 (streak 91).
# Episode 122 finished after 16.000000 time steps with total reward = 0.936000 (streak 92).
# Episode 123 finished after 16.000000 time steps with total reward = 0.936000 (streak 93).
# Episode 124 finished after 16.000000 time steps with total reward = 0.936000 (streak 94).
# Episode 125 finished after 16.000000 time steps with total reward = 0.936000 (streak 95).
# Episode 126 finished after 16.000000 time steps with total reward = 0.936000 (streak 96).
# Episode 127 finished after 16.000000 time steps with total reward = 0.936000 (streak 97).
# Episode 128 finished after 16.000000 time steps with total reward = 0.936000 (streak 98).
# Episode 129 finished after 548.000000 time steps with total reward = -1.192000 (streak 99).
# Episode 130 finished after 17.000000 time steps with total reward = 0.932000 (streak 0).
# Episode 131 finished after 10.000000 time steps with total reward = 0.960000 (streak 1).
# Episode 132 finished after 10.000000 time steps with total reward = 0.960000 (streak 2).
# Episode 133 finished after 10.000000 time steps with total reward = 0.960000 (streak 3).
# Episode 134 finished after 10.000000 time steps with total reward = 0.960000 (streak 4).
# Episode 135 finished after 10.000000 time steps with total reward = 0.960000 (streak 5).
# Episode 136 finished after 10.000000 time steps with total reward = 0.960000 (streak 6).
# Episode 137 finished after 10.000000 time steps with total reward = 0.960000 (streak 7).
# Episode 138 finished after 10.000000 time steps with total reward = 0.960000 (streak 8).
# Episode 139 finished after 10.000000 time steps with total reward = 0.960000 (streak 9).
# Episode 140 finished after 10.000000 time steps with total reward = 0.960000 (streak 10).
# Episode 141 finished after 10.000000 time steps with total reward = 0.960000 (streak 11).
# Episode 142 finished after 10.000000 time steps with total reward = 0.960000 (streak 12).
# Episode 143 finished after 10.000000 time steps with total reward = 0.960000 (streak 13).
# Episode 144 finished after 10.000000 time steps with total reward = 0.960000 (streak 14).
# Episode 145 finished after 10.000000 time steps with total reward = 0.960000 (streak 15).
# Episode 146 finished after 10.000000 time steps with total reward = 0.960000 (streak 16).
# Episode 147 finished after 10.000000 time steps with total reward = 0.960000 (streak 17).
# Episode 148 finished after 10.000000 time steps with total reward = 0.960000 (streak 18).
# Episode 149 finished after 10.000000 time steps with total reward = 0.960000 (streak 19).
# Episode 150 finished after 10.000000 time steps with total reward = 0.960000 (streak 20).
# Episode 151 finished after 10.000000 time steps with total reward = 0.960000 (streak 21).
# Episode 152 finished after 10.000000 time steps with total reward = 0.960000 (streak 22).
# Episode 153 finished after 10.000000 time steps with total reward = 0.960000 (streak 23).
# Episode 154 finished after 10.000000 time steps with total reward = 0.960000 (streak 24).
# Episode 155 finished after 10.000000 time steps with total reward = 0.960000 (streak 25).
# Episode 156 finished after 10.000000 time steps with total reward = 0.960000 (streak 26).
# Episode 157 finished after 10.000000 time steps with total reward = 0.960000 (streak 27).
# Episode 158 finished after 10.000000 time steps with total reward = 0.960000 (streak 28).
# Episode 159 finished after 10.000000 time steps with total reward = 0.960000 (streak 29).
# Episode 160 finished after 10.000000 time steps with total reward = 0.960000 (streak 30).
# Episode 161 finished after 10.000000 time steps with total reward = 0.960000 (streak 31).
# Episode 162 finished after 10.000000 time steps with total reward = 0.960000 (streak 32).
# Episode 163 finished after 10.000000 time steps with total reward = 0.960000 (streak 33).
# Episode 164 finished after 10.000000 time steps with total reward = 0.960000 (streak 34).
# Episode 165 finished after 10.000000 time steps with total reward = 0.960000 (streak 35).
# Episode 166 finished after 10.000000 time steps with total reward = 0.960000 (streak 36).
# Episode 167 finished after 10.000000 time steps with total reward = 0.960000 (streak 37).
# Episode 168 finished after 10.000000 time steps with total reward = 0.960000 (streak 38).
# Episode 169 finished after 10.000000 time steps with total reward = 0.960000 (streak 39).
# Episode 170 finished after 10.000000 time steps with total reward = 0.960000 (streak 40).
# Episode 171 finished after 10.000000 time steps with total reward = 0.960000 (streak 41).
# Episode 172 finished after 10.000000 time steps with total reward = 0.960000 (streak 42).
# Episode 173 finished after 10.000000 time steps with total reward = 0.960000 (streak 43).
# Episode 174 finished after 10.000000 time steps with total reward = 0.960000 (streak 44).
# Episode 175 finished after 10.000000 time steps with total reward = 0.960000 (streak 45).
# Episode 176 finished after 10.000000 time steps with total reward = 0.960000 (streak 46).
# Episode 177 finished after 10.000000 time steps with total reward = 0.960000 (streak 47).
# Episode 178 finished after 10.000000 time steps with total reward = 0.960000 (streak 48).
# Episode 179 finished after 10.000000 time steps with total reward = 0.960000 (streak 49).
# Episode 180 finished after 10.000000 time steps with total reward = 0.960000 (streak 50).
# Episode 181 finished after 10.000000 time steps with total reward = 0.960000 (streak 51).
# Episode 182 finished after 10.000000 time steps with total reward = 0.960000 (streak 52).
# Episode 183 finished after 10.000000 time steps with total reward = 0.960000 (streak 53).
# Episode 184 finished after 10.000000 time steps with total reward = 0.960000 (streak 54).
# Episode 185 finished after 10.000000 time steps with total reward = 0.960000 (streak 55).
# Episode 186 finished after 10.000000 time steps with total reward = 0.960000 (streak 56).
# Episode 187 finished after 10.000000 time steps with total reward = 0.960000 (streak 57).
# Episode 188 finished after 10.000000 time steps with total reward = 0.960000 (streak 58).
# Episode 189 finished after 10.000000 time steps with total reward = 0.960000 (streak 59).
# Episode 190 finished after 10.000000 time steps with total reward = 0.960000 (streak 60).
# Episode 191 finished after 10.000000 time steps with total reward = 0.960000 (streak 61).
# Episode 192 finished after 10.000000 time steps with total reward = 0.960000 (streak 62).
# Episode 193 finished after 10.000000 time steps with total reward = 0.960000 (streak 63).
# Episode 194 finished after 10.000000 time steps with total reward = 0.960000 (streak 64).
# Episode 195 finished after 10.000000 time steps with total reward = 0.960000 (streak 65).
# Episode 196 finished after 10.000000 time steps with total reward = 0.960000 (streak 66).
# Episode 197 finished after 10.000000 time steps with total reward = 0.960000 (streak 67).
# Episode 198 finished after 10.000000 time steps with total reward = 0.960000 (streak 68).
# Episode 199 finished after 10.000000 time steps with total reward = 0.960000 (streak 69).
# Episode 200 finished after 10.000000 time steps with total reward = 0.960000 (streak 70).
# Episode 201 finished after 10.000000 time steps with total reward = 0.960000 (streak 71).
# Episode 202 finished after 10.000000 time steps with total reward = 0.960000 (streak 72).
# Episode 203 finished after 10.000000 time steps with total reward = 0.960000 (streak 73).
# Episode 204 finished after 10.000000 time steps with total reward = 0.960000 (streak 74).
# Episode 205 finished after 10.000000 time steps with total reward = 0.960000 (streak 75).
# Episode 206 finished after 10.000000 time steps with total reward = 0.960000 (streak 76).
# Episode 207 finished after 10.000000 time steps with total reward = 0.960000 (streak 77).
# Episode 208 finished after 10.000000 time steps with total reward = 0.960000 (streak 78).
# Episode 209 finished after 10.000000 time steps with total reward = 0.960000 (streak 79).
# Episode 210 finished after 10.000000 time steps with total reward = 0.960000 (streak 80).
# Episode 211 finished after 10.000000 time steps with total reward = 0.960000 (streak 81).
# Episode 212 finished after 10.000000 time steps with total reward = 0.960000 (streak 82).
# Episode 213 finished after 10.000000 time steps with total reward = 0.960000 (streak 83).
# Episode 214 finished after 10.000000 time steps with total reward = 0.960000 (streak 84).
# Episode 215 finished after 10.000000 time steps with total reward = 0.960000 (streak 85).
# Episode 216 finished after 10.000000 time steps with total reward = 0.960000 (streak 86).
# Episode 217 finished after 10.000000 time steps with total reward = 0.960000 (streak 87).
# Episode 218 finished after 10.000000 time steps with total reward = 0.960000 (streak 88).
# Episode 219 finished after 10.000000 time steps with total reward = 0.960000 (streak 89).
# Episode 220 finished after 10.000000 time steps with total reward = 0.960000 (streak 90).
# Episode 221 finished after 11.000000 time steps with total reward = 0.956000 (streak 91).
# Episode 222 finished after 10.000000 time steps with total reward = 0.960000 (streak 92).
# Episode 223 finished after 10.000000 time steps with total reward = 0.960000 (streak 93).
# Episode 224 finished after 10.000000 time steps with total reward = 0.960000 (streak 94).
# Episode 225 finished after 10.000000 time steps with total reward = 0.960000 (streak 95).
# Episode 226 finished after 10.000000 time steps with total reward = 0.960000 (streak 96).
# Episode 227 finished after 10.000000 time steps with total reward = 0.960000 (streak 97).
# Episode 228 finished after 10.000000 time steps with total reward = 0.960000 (streak 98).
# Episode 229 finished after 10.000000 time steps with total reward = 0.960000 (streak 99).
# Episode 230 finished after 10.000000 time steps with total reward = 0.960000 (streak 100).
# Episode 0 finished after 68.000000 time steps with total reward = 0.728000 (streak 0).
# Episode 1 finished after 231.000000 time steps with total reward = 0.076000 (streak 0).
# Episode 2 finished after 154.000000 time steps with total reward = 0.384000 (streak 0).
# Episode 3 finished after 111.000000 time steps with total reward = 0.556000 (streak 0).
# Episode 4 finished after 211.000000 time steps with total reward = 0.156000 (streak 0).
# Episode 5 finished after 151.000000 time steps with total reward = 0.396000 (streak 0).
# Episode 6 finished after 41.000000 time steps with total reward = 0.836000 (streak 0).
# Episode 7 finished after 101.000000 time steps with total reward = 0.596000 (streak 0).
# Episode 8 finished after 388.000000 time steps with total reward = -0.552000 (streak 0).
# Episode 9 finished after 119.000000 time steps with total reward = 0.524000 (streak 0).
# Episode 10 finished after 137.000000 time steps with total reward = 0.452000 (streak 0).
# Episode 11 finished after 65.000000 time steps with total reward = 0.740000 (streak 0).
# Episode 12 finished after 55.000000 time steps with total reward = 0.780000 (streak 0).
# Episode 13 finished after 39.000000 time steps with total reward = 0.844000 (streak 0).
# Episode 14 finished after 45.000000 time steps with total reward = 0.820000 (streak 0).
# Episode 15 finished after 54.000000 time steps with total reward = 0.784000 (streak 0).
# Episode 16 finished after 311.000000 time steps with total reward = -0.244000 (streak 0).
# Episode 17 finished after 94.000000 time steps with total reward = 0.624000 (streak 0).
# Episode 18 finished after 54.000000 time steps with total reward = 0.784000 (streak 0).
# Episode 19 finished after 235.000000 time steps with total reward = 0.060000 (streak 0).
# Episode 20 finished after 118.000000 time steps with total reward = 0.528000 (streak 0).
# Episode 21 finished after 23.000000 time steps with total reward = 0.908000 (streak 0).
# Episode 22 finished after 202.000000 time steps with total reward = 0.192000 (streak 1).
# Episode 23 finished after 35.000000 time steps with total reward = 0.860000 (streak 0).
# Episode 24 finished after 20.000000 time steps with total reward = 0.920000 (streak 0).
# Episode 25 finished after 16.000000 time steps with total reward = 0.936000 (streak 1).
# Episode 26 finished after 11.000000 time steps with total reward = 0.956000 (streak 2).
# Episode 27 finished after 15.000000 time steps with total reward = 0.940000 (streak 3).
# Episode 28 finished after 20.000000 time steps with total reward = 0.920000 (streak 4).
# Episode 29 finished after 20.000000 time steps with total reward = 0.920000 (streak 5).
# Episode 30 finished after 22.000000 time steps with total reward = 0.912000 (streak 6).
# Episode 31 finished after 26.000000 time steps with total reward = 0.896000 (streak 7).
# Episode 32 finished after 26.000000 time steps with total reward = 0.896000 (streak 0).
# Episode 33 finished after 23.000000 time steps with total reward = 0.908000 (streak 0).
# Episode 34 finished after 29.000000 time steps with total reward = 0.884000 (streak 1).
# Episode 35 finished after 31.000000 time steps with total reward = 0.876000 (streak 0).
# Episode 36 finished after 33.000000 time steps with total reward = 0.868000 (streak 0).
# Episode 37 finished after 50.000000 time steps with total reward = 0.800000 (streak 0).
# Episode 38 finished after 10.000000 time steps with total reward = 0.960000 (streak 0).
# Episode 39 finished after 10.000000 time steps with total reward = 0.960000 (streak 1).
# Episode 40 finished after 10.000000 time steps with total reward = 0.960000 (streak 2).
# Episode 41 finished after 10.000000 time steps with total reward = 0.960000 (streak 3).
# Episode 42 finished after 10.000000 time steps with total reward = 0.960000 (streak 4).
# Episode 43 finished after 10.000000 time steps with total reward = 0.960000 (streak 5).
# Episode 44 finished after 10.000000 time steps with total reward = 0.960000 (streak 6).
# Episode 45 finished after 10.000000 time steps with total reward = 0.960000 (streak 7).
# Episode 46 finished after 10.000000 time steps with total reward = 0.960000 (streak 8).
# Episode 47 finished after 10.000000 time steps with total reward = 0.960000 (streak 9).
# Episode 48 finished after 10.000000 time steps with total reward = 0.960000 (streak 10).
# Episode 49 finished after 10.000000 time steps with total reward = 0.960000 (streak 11).
# Episode 50 finished after 10.000000 time steps with total reward = 0.960000 (streak 12).
# Episode 51 finished after 10.000000 time steps with total reward = 0.960000 (streak 13).
# Episode 52 finished after 10.000000 time steps with total reward = 0.960000 (streak 14).
# Episode 53 finished after 10.000000 time steps with total reward = 0.960000 (streak 15).
# Episode 54 finished after 10.000000 time steps with total reward = 0.960000 (streak 16).
# Episode 55 finished after 10.000000 time steps with total reward = 0.960000 (streak 17).
# Episode 56 finished after 10.000000 time steps with total reward = 0.960000 (streak 18).
# Episode 57 finished after 10.000000 time steps with total reward = 0.960000 (streak 19).
# Episode 58 finished after 10.000000 time steps with total reward = 0.960000 (streak 20).
# Episode 59 finished after 10.000000 time steps with total reward = 0.960000 (streak 21).
# Episode 60 finished after 10.000000 time steps with total reward = 0.960000 (streak 22).
# Episode 61 finished after 10.000000 time steps with total reward = 0.960000 (streak 23).
# Episode 62 finished after 10.000000 time steps with total reward = 0.960000 (streak 24).
# Episode 63 finished after 10.000000 time steps with total reward = 0.960000 (streak 25).
# Episode 64 finished after 10.000000 time steps with total reward = 0.960000 (streak 26).
# Episode 65 finished after 10.000000 time steps with total reward = 0.960000 (streak 27).
# Episode 66 finished after 10.000000 time steps with total reward = 0.960000 (streak 28).
# Episode 67 finished after 10.000000 time steps with total reward = 0.960000 (streak 29).
# Episode 68 finished after 10.000000 time steps with total reward = 0.960000 (streak 30).
# Episode 69 finished after 10.000000 time steps with total reward = 0.960000 (streak 31).
# Episode 70 finished after 10.000000 time steps with total reward = 0.960000 (streak 32).
# Episode 71 finished after 10.000000 time steps with total reward = 0.960000 (streak 33).
# Episode 72 finished after 10.000000 time steps with total reward = 0.960000 (streak 34).
# Episode 73 finished after 10.000000 time steps with total reward = 0.960000 (streak 35).
# Episode 74 finished after 10.000000 time steps with total reward = 0.960000 (streak 36).
# Episode 75 finished after 10.000000 time steps with total reward = 0.960000 (streak 37).
# Episode 76 finished after 10.000000 time steps with total reward = 0.960000 (streak 38).
# Episode 77 finished after 10.000000 time steps with total reward = 0.960000 (streak 39).
# Episode 78 finished after 10.000000 time steps with total reward = 0.960000 (streak 40).
# Episode 79 finished after 10.000000 time steps with total reward = 0.960000 (streak 41).
# Episode 80 finished after 16.000000 time steps with total reward = 0.936000 (streak 42).
# Episode 81 finished after 10.000000 time steps with total reward = 0.960000 (streak 43).
# Episode 82 finished after 10.000000 time steps with total reward = 0.960000 (streak 44).
# Episode 83 finished after 10.000000 time steps with total reward = 0.960000 (streak 45).
# Episode 84 finished after 10.000000 time steps with total reward = 0.960000 (streak 46).
# Episode 85 finished after 10.000000 time steps with total reward = 0.960000 (streak 47).
# Episode 86 finished after 10.000000 time steps with total reward = 0.960000 (streak 48).
# Episode 87 finished after 10.000000 time steps with total reward = 0.960000 (streak 49).
# Episode 88 finished after 10.000000 time steps with total reward = 0.960000 (streak 50).
# Episode 89 finished after 10.000000 time steps with total reward = 0.960000 (streak 51).
# Episode 90 finished after 10.000000 time steps with total reward = 0.960000 (streak 52).
# Episode 91 finished after 10.000000 time steps with total reward = 0.960000 (streak 53).
# Episode 92 finished after 10.000000 time steps with total reward = 0.960000 (streak 54).
# Episode 93 finished after 10.000000 time steps with total reward = 0.960000 (streak 55).
# Episode 94 finished after 10.000000 time steps with total reward = 0.960000 (streak 56).
# Episode 95 finished after 10.000000 time steps with total reward = 0.960000 (streak 57).
# Episode 96 finished after 10.000000 time steps with total reward = 0.960000 (streak 58).
# Episode 97 finished after 10.000000 time steps with total reward = 0.960000 (streak 59).
# Episode 98 finished after 10.000000 time steps with total reward = 0.960000 (streak 60).
# Episode 99 finished after 10.000000 time steps with total reward = 0.960000 (streak 61).
# Episode 100 finished after 10.000000 time steps with total reward = 0.960000 (streak 62).
# Episode 101 finished after 10.000000 time steps with total reward = 0.960000 (streak 63).
# Episode 102 finished after 10.000000 time steps with total reward = 0.960000 (streak 64).
# Episode 103 finished after 10.000000 time steps with total reward = 0.960000 (streak 65).
# Episode 104 finished after 10.000000 time steps with total reward = 0.960000 (streak 66).
# Episode 105 finished after 10.000000 time steps with total reward = 0.960000 (streak 67).
# Episode 106 finished after 10.000000 time steps with total reward = 0.960000 (streak 68).
# Episode 107 finished after 10.000000 time steps with total reward = 0.960000 (streak 69).
# Episode 108 finished after 10.000000 time steps with total reward = 0.960000 (streak 70).
# Episode 109 finished after 10.000000 time steps with total reward = 0.960000 (streak 71).
# Episode 110 finished after 10.000000 time steps with total reward = 0.960000 (streak 72).
# Episode 111 finished after 10.000000 time steps with total reward = 0.960000 (streak 73).
# Episode 112 finished after 10.000000 time steps with total reward = 0.960000 (streak 74).
# Episode 113 finished after 10.000000 time steps with total reward = 0.960000 (streak 75).
# Episode 114 finished after 10.000000 time steps with total reward = 0.960000 (streak 76).
# Episode 115 finished after 10.000000 time steps with total reward = 0.960000 (streak 77).
# Episode 116 finished after 10.000000 time steps with total reward = 0.960000 (streak 78).
# Episode 117 finished after 10.000000 time steps with total reward = 0.960000 (streak 79).
# Episode 118 finished after 10.000000 time steps with total reward = 0.960000 (streak 80).
# Episode 119 finished after 10.000000 time steps with total reward = 0.960000 (streak 81).
# Episode 120 finished after 10.000000 time steps with total reward = 0.960000 (streak 82).
# Episode 121 finished after 10.000000 time steps with total reward = 0.960000 (streak 83).
# Episode 122 finished after 10.000000 time steps with total reward = 0.960000 (streak 84).
# Episode 123 finished after 10.000000 time steps with total reward = 0.960000 (streak 85).
# Episode 124 finished after 10.000000 time steps with total reward = 0.960000 (streak 86).
# Episode 125 finished after 10.000000 time steps with total reward = 0.960000 (streak 87).
# Episode 126 finished after 10.000000 time steps with total reward = 0.960000 (streak 88).
# Episode 127 finished after 10.000000 time steps with total reward = 0.960000 (streak 89).
# Episode 128 finished after 10.000000 time steps with total reward = 0.960000 (streak 90).
# Episode 129 finished after 10.000000 time steps with total reward = 0.960000 (streak 91).
# Episode 130 finished after 10.000000 time steps with total reward = 0.960000 (streak 92).
# Episode 131 finished after 10.000000 time steps with total reward = 0.960000 (streak 93).
# Episode 132 finished after 10.000000 time steps with total reward = 0.960000 (streak 94).
# Episode 133 finished after 10.000000 time steps with total reward = 0.960000 (streak 95).
# Episode 134 finished after 10.000000 time steps with total reward = 0.960000 (streak 96).
# Episode 135 finished after 10.000000 time steps with total reward = 0.960000 (streak 97).
# Episode 136 finished after 10.000000 time steps with total reward = 0.960000 (streak 98).
# Episode 137 finished after 10.000000 time steps with total reward = 0.960000 (streak 99).
# Episode 138 finished after 10.000000 time steps with total reward = 0.960000 (streak 100).
# Episode 0 finished after 171.000000 time steps with total reward = 0.316000 (streak 0).
# Episode 1 finished after 346.000000 time steps with total reward = -0.384000 (streak 0).
# Episode 2 finished after 102.000000 time steps with total reward = 0.592000 (streak 0).
# Episode 3 finished after 232.000000 time steps with total reward = 0.072000 (streak 0).
# Episode 4 finished after 241.000000 time steps with total reward = 0.036000 (streak 0).
# Episode 5 finished after 247.000000 time steps with total reward = 0.012000 (streak 0).
# Episode 6 finished after 216.000000 time steps with total reward = 0.136000 (streak 0).
# Episode 7 finished after 223.000000 time steps with total reward = 0.108000 (streak 0).
# Episode 8 finished after 352.000000 time steps with total reward = -0.408000 (streak 0).
# Episode 9 finished after 13.000000 time steps with total reward = 0.948000 (streak 0).
# Episode 10 finished after 261.000000 time steps with total reward = -0.044000 (streak 1).
# Episode 11 finished after 45.000000 time steps with total reward = 0.820000 (streak 0).
# Episode 12 finished after 177.000000 time steps with total reward = 0.292000 (streak 0).
# Episode 13 finished after 53.000000 time steps with total reward = 0.788000 (streak 0).
# Episode 14 finished after 89.000000 time steps with total reward = 0.644000 (streak 0).
# Episode 15 finished after 96.000000 time steps with total reward = 0.616000 (streak 0).
# Episode 16 finished after 17.000000 time steps with total reward = 0.932000 (streak 0).
# Episode 17 finished after 16.000000 time steps with total reward = 0.936000 (streak 1).
# Episode 18 finished after 17.000000 time steps with total reward = 0.932000 (streak 2).
# Episode 19 finished after 10.000000 time steps with total reward = 0.960000 (streak 3).
# Episode 20 finished after 29.000000 time steps with total reward = 0.884000 (streak 4).
# Episode 21 finished after 29.000000 time steps with total reward = 0.884000 (streak 0).
# Episode 22 finished after 20.000000 time steps with total reward = 0.920000 (streak 0).
# Episode 23 finished after 59.000000 time steps with total reward = 0.764000 (streak 1).
# Episode 24 finished after 26.000000 time steps with total reward = 0.896000 (streak 0).
# Episode 25 finished after 29.000000 time steps with total reward = 0.884000 (streak 0).
# Episode 26 finished after 59.000000 time steps with total reward = 0.764000 (streak 0).
# Episode 27 finished after 54.000000 time steps with total reward = 0.784000 (streak 0).
# Episode 28 finished after 43.000000 time steps with total reward = 0.828000 (streak 0).
# Episode 29 finished after 103.000000 time steps with total reward = 0.588000 (streak 0).
# Episode 30 finished after 34.000000 time steps with total reward = 0.864000 (streak 0).
# Episode 31 finished after 80.000000 time steps with total reward = 0.680000 (streak 0).
# Episode 32 finished after 34.000000 time steps with total reward = 0.864000 (streak 0).
# Episode 33 finished after 716.000000 time steps with total reward = -1.864000 (streak 0).
# Episode 34 finished after 25.000000 time steps with total reward = 0.900000 (streak 0).
# Episode 35 finished after 47.000000 time steps with total reward = 0.812000 (streak 1).
# Episode 36 finished after 27.000000 time steps with total reward = 0.892000 (streak 0).
# Episode 37 finished after 109.000000 time steps with total reward = 0.564000 (streak 0).
# Episode 38 finished after 121.000000 time steps with total reward = 0.516000 (streak 0).
# Episode 39 finished after 175.000000 time steps with total reward = 0.300000 (streak 0).
# Episode 40 finished after 179.000000 time steps with total reward = 0.284000 (streak 0).
# Episode 41 finished after 32.000000 time steps with total reward = 0.872000 (streak 0).
# Episode 42 finished after 30.000000 time steps with total reward = 0.880000 (streak 0).
# Episode 43 finished after 58.000000 time steps with total reward = 0.768000 (streak 0).
# Episode 44 finished after 36.000000 time steps with total reward = 0.856000 (streak 0).
# Episode 45 finished after 24.000000 time steps with total reward = 0.904000 (streak 0).
# Episode 46 finished after 47.000000 time steps with total reward = 0.812000 (streak 1).
# Episode 47 finished after 38.000000 time steps with total reward = 0.848000 (streak 0).
# Episode 48 finished after 69.000000 time steps with total reward = 0.724000 (streak 0).
# Episode 49 finished after 76.000000 time steps with total reward = 0.696000 (streak 0).
# Episode 50 finished after 81.000000 time steps with total reward = 0.676000 (streak 0).
# Episode 51 finished after 126.000000 time steps with total reward = 0.496000 (streak 0).
# Episode 52 finished after 36.000000 time steps with total reward = 0.856000 (streak 0).
# Episode 53 finished after 75.000000 time steps with total reward = 0.700000 (streak 0).
# Episode 54 finished after 72.000000 time steps with total reward = 0.712000 (streak 0).
# Episode 55 finished after 29.000000 time steps with total reward = 0.884000 (streak 0).
# Episode 56 finished after 221.000000 time steps with total reward = 0.116000 (streak 0).
# Episode 57 finished after 41.000000 time steps with total reward = 0.836000 (streak 0).
# Episode 58 finished after 473.000000 time steps with total reward = -0.892000 (streak 0).
# Episode 59 finished after 17.000000 time steps with total reward = 0.932000 (streak 0).
# Episode 60 finished after 92.000000 time steps with total reward = 0.632000 (streak 1).
# Episode 61 finished after 72.000000 time steps with total reward = 0.712000 (streak 0).
# Episode 62 finished after 44.000000 time steps with total reward = 0.824000 (streak 0).
# Episode 63 finished after 246.000000 time steps with total reward = 0.016000 (streak 0).
# Episode 64 finished after 37.000000 time steps with total reward = 0.852000 (streak 0).
# Episode 65 finished after 146.000000 time steps with total reward = 0.416000 (streak 0).
# Episode 66 finished after 53.000000 time steps with total reward = 0.788000 (streak 0).
# Episode 67 finished after 8.000000 time steps with total reward = 0.968000 (streak 0).
# Episode 68 finished after 8.000000 time steps with total reward = 0.968000 (streak 1).
# Episode 69 finished after 8.000000 time steps with total reward = 0.968000 (streak 2).
# Episode 70 finished after 8.000000 time steps with total reward = 0.968000 (streak 3).
# Episode 71 finished after 8.000000 time steps with total reward = 0.968000 (streak 4).
# Episode 72 finished after 8.000000 time steps with total reward = 0.968000 (streak 5).
# Episode 73 finished after 8.000000 time steps with total reward = 0.968000 (streak 6).
# Episode 74 finished after 8.000000 time steps with total reward = 0.968000 (streak 7).
# Episode 75 finished after 8.000000 time steps with total reward = 0.968000 (streak 8).
# Episode 76 finished after 8.000000 time steps with total reward = 0.968000 (streak 9).
# Episode 77 finished after 8.000000 time steps with total reward = 0.968000 (streak 10).
# Episode 78 finished after 8.000000 time steps with total reward = 0.968000 (streak 11).
# Episode 79 finished after 8.000000 time steps with total reward = 0.968000 (streak 12).
# Episode 80 finished after 8.000000 time steps with total reward = 0.968000 (streak 13).
# Episode 81 finished after 8.000000 time steps with total reward = 0.968000 (streak 14).
# Episode 82 finished after 8.000000 time steps with total reward = 0.968000 (streak 15).
# Episode 83 finished after 8.000000 time steps with total reward = 0.968000 (streak 16).
# Episode 84 finished after 8.000000 time steps with total reward = 0.968000 (streak 17).
# Episode 85 finished after 8.000000 time steps with total reward = 0.968000 (streak 18).
# Episode 86 finished after 8.000000 time steps with total reward = 0.968000 (streak 19).
# Episode 87 finished after 8.000000 time steps with total reward = 0.968000 (streak 20).
# Episode 88 finished after 8.000000 time steps with total reward = 0.968000 (streak 21).
# Episode 89 finished after 8.000000 time steps with total reward = 0.968000 (streak 22).
# Episode 90 finished after 8.000000 time steps with total reward = 0.968000 (streak 23).
# Episode 91 finished after 8.000000 time steps with total reward = 0.968000 (streak 24).
# Episode 92 finished after 8.000000 time steps with total reward = 0.968000 (streak 25).
# Episode 93 finished after 8.000000 time steps with total reward = 0.968000 (streak 26).
# Episode 94 finished after 8.000000 time steps with total reward = 0.968000 (streak 27).
# Episode 95 finished after 8.000000 time steps with total reward = 0.968000 (streak 28).
# Episode 96 finished after 8.000000 time steps with total reward = 0.968000 (streak 29).
# Episode 97 finished after 8.000000 time steps with total reward = 0.968000 (streak 30).
# Episode 98 finished after 8.000000 time steps with total reward = 0.968000 (streak 31).
# Episode 99 finished after 8.000000 time steps with total reward = 0.968000 (streak 32).
# Episode 100 finished after 8.000000 time steps with total reward = 0.968000 (streak 33).
# Episode 101 finished after 8.000000 time steps with total reward = 0.968000 (streak 34).
# Episode 102 finished after 8.000000 time steps with total reward = 0.968000 (streak 35).
# Episode 103 finished after 8.000000 time steps with total reward = 0.968000 (streak 36).
# Episode 104 finished after 8.000000 time steps with total reward = 0.968000 (streak 37).
# Episode 105 finished after 8.000000 time steps with total reward = 0.968000 (streak 38).
# Episode 106 finished after 8.000000 time steps with total reward = 0.968000 (streak 39).
# Episode 107 finished after 8.000000 time steps with total reward = 0.968000 (streak 40).
# Episode 108 finished after 8.000000 time steps with total reward = 0.968000 (streak 41).
# Episode 109 finished after 8.000000 time steps with total reward = 0.968000 (streak 42).
# Episode 110 finished after 8.000000 time steps with total reward = 0.968000 (streak 43).
# Episode 111 finished after 8.000000 time steps with total reward = 0.968000 (streak 44).
# Episode 112 finished after 8.000000 time steps with total reward = 0.968000 (streak 45).
# Episode 113 finished after 8.000000 time steps with total reward = 0.968000 (streak 46).
# Episode 114 finished after 8.000000 time steps with total reward = 0.968000 (streak 47).
# Episode 115 finished after 8.000000 time steps with total reward = 0.968000 (streak 48).
# Episode 116 finished after 8.000000 time steps with total reward = 0.968000 (streak 49).
# Episode 117 finished after 8.000000 time steps with total reward = 0.968000 (streak 50).
# Episode 118 finished after 8.000000 time steps with total reward = 0.968000 (streak 51).
# Episode 119 finished after 8.000000 time steps with total reward = 0.968000 (streak 52).
# Episode 120 finished after 8.000000 time steps with total reward = 0.968000 (streak 53).
# Episode 121 finished after 8.000000 time steps with total reward = 0.968000 (streak 54).
# Episode 122 finished after 8.000000 time steps with total reward = 0.968000 (streak 55).
# Episode 123 finished after 8.000000 time steps with total reward = 0.968000 (streak 56).
# Episode 124 finished after 8.000000 time steps with total reward = 0.968000 (streak 57).
# Episode 125 finished after 8.000000 time steps with total reward = 0.968000 (streak 58).
# Episode 126 finished after 8.000000 time steps with total reward = 0.968000 (streak 59).
# Episode 127 finished after 8.000000 time steps with total reward = 0.968000 (streak 60).
# Episode 128 finished after 8.000000 time steps with total reward = 0.968000 (streak 61).
# Episode 129 finished after 8.000000 time steps with total reward = 0.968000 (streak 62).
# Episode 130 finished after 8.000000 time steps with total reward = 0.968000 (streak 63).
# Episode 131 finished after 8.000000 time steps with total reward = 0.968000 (streak 64).
# Episode 132 finished after 8.000000 time steps with total reward = 0.968000 (streak 65).
# Episode 133 finished after 8.000000 time steps with total reward = 0.968000 (streak 66).
# Episode 134 finished after 8.000000 time steps with total reward = 0.968000 (streak 67).
# Episode 135 finished after 8.000000 time steps with total reward = 0.968000 (streak 68).
# Episode 136 finished after 8.000000 time steps with total reward = 0.968000 (streak 69).
# Episode 137 finished after 8.000000 time steps with total reward = 0.968000 (streak 70).
# Episode 138 finished after 8.000000 time steps with total reward = 0.968000 (streak 71).
# Episode 139 finished after 8.000000 time steps with total reward = 0.968000 (streak 72).
# Episode 140 finished after 8.000000 time steps with total reward = 0.968000 (streak 73).
# Episode 141 finished after 8.000000 time steps with total reward = 0.968000 (streak 74).
# Episode 142 finished after 8.000000 time steps with total reward = 0.968000 (streak 75).
# Episode 143 finished after 8.000000 time steps with total reward = 0.968000 (streak 76).
# Episode 144 finished after 8.000000 time steps with total reward = 0.968000 (streak 77).
# Episode 145 finished after 8.000000 time steps with total reward = 0.968000 (streak 78).
# Episode 146 finished after 8.000000 time steps with total reward = 0.968000 (streak 79).
# Episode 147 finished after 8.000000 time steps with total reward = 0.968000 (streak 80).
# Episode 148 finished after 8.000000 time steps with total reward = 0.968000 (streak 81).
# Episode 149 finished after 8.000000 time steps with total reward = 0.968000 (streak 82).
# Episode 150 finished after 8.000000 time steps with total reward = 0.968000 (streak 83).
# Episode 151 finished after 8.000000 time steps with total reward = 0.968000 (streak 84).
# Episode 152 finished after 8.000000 time steps with total reward = 0.968000 (streak 85).
# Episode 153 finished after 8.000000 time steps with total reward = 0.968000 (streak 86).
# Episode 154 finished after 8.000000 time steps with total reward = 0.968000 (streak 87).
# Episode 155 finished after 8.000000 time steps with total reward = 0.968000 (streak 88).
# Episode 156 finished after 8.000000 time steps with total reward = 0.968000 (streak 89).
# Episode 157 finished after 8.000000 time steps with total reward = 0.968000 (streak 90).
# Episode 158 finished after 8.000000 time steps with total reward = 0.968000 (streak 91).
# Episode 159 finished after 8.000000 time steps with total reward = 0.968000 (streak 92).
# Episode 160 finished after 8.000000 time steps with total reward = 0.968000 (streak 93).
# Episode 161 finished after 8.000000 time steps with total reward = 0.968000 (streak 94).
# Episode 162 finished after 8.000000 time steps with total reward = 0.968000 (streak 95).
# Episode 163 finished after 8.000000 time steps with total reward = 0.968000 (streak 96).
# Episode 164 finished after 8.000000 time steps with total reward = 0.968000 (streak 97).
# Episode 165 finished after 8.000000 time steps with total reward = 0.968000 (streak 98).
# Episode 166 finished after 8.000000 time steps with total reward = 0.968000 (streak 99).
# Episode 167 finished after 8.000000 time steps with total reward = 0.968000 (streak 100).

# %% [markdown]
# # Plot Q-Learning Results

# %%
import os
titles = ['Close','Mid','Far']
path = "data/Q_learning/Portals/"
# path = "data/Q_learning/NoPortals/"
i=0
for tuple_ in Results:
    #save into files
    if not os.path.exists(path):
        os.makedirs(path)
    np.save(path+f"{titles[i]}",tuple_)
    i+=1

# %% [markdown]
# # SARSA

# %%
Results = []
for goal in Goals:
    #to store the results for current goal
    S_timeSteps_list = []
    S_TotalReward_list = []
    S_Episodes_list = []
    #restarting the q_table
    q_table = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,), dtype=float)
    #changing goals
    env.maze_view.change_goal(goal)
    # Instantiating the learning related parameters
    learning_rate = get_learning_rate(0)
    explore_rate = get_explore_rate(0)
    discount_factor = 0.99

    num_streaks = 0

    # Render tha maze
    env.render()

    for episode in range(NUM_EPISODES):

        # Reset the environment
        obv = env.reset()

        # the initial state
        state_0 = state_to_bucket(obv)
        total_reward = 0

        for t in range(MAX_T):

            # execute the action
            obv, reward, done, _ = env.step(action)

            # Observe the result
            state = state_to_bucket(obv)
            total_reward += reward

            # Select an action
            action_new = select_action(state, explore_rate,q_table)

            # Update the Q based on the result
            #best_q = np.amax(q_table[state])
            #q_table[state_0 + (action,)] += learning_rate * (reward + discount_factor * (best_q) - q_table[state_0 + (action,)])
            q_table[state_0 + (action,)] += learning_rate * (reward + discount_factor * q_table[state + (action_new,)] - q_table[state_0 + (action,)])

            # Setting up for the next iteration
            state_0 = state
            action = action_new

            # Render tha maze
            if RENDER_MAZE:
                env.render()

            if env.is_game_over():
                sys.exit()

            if done:
                print("Episode %d finished after %f time steps with total reward = %f (streak %d)."
                      % (episode, t, total_reward, num_streaks))
                S_Episodes_list.append(episode)
                S_timeSteps_list.append(t)
                S_TotalReward_list.append(total_reward)

                if t <= SOLVED_T:
                    num_streaks += 1
                else:
                    num_streaks = 0
                break

            elif t >= MAX_T - 1:
                print("Episode %d timed out at %d with total reward = %f."
                      % (episode, t, total_reward))

        # It's considered done when it's solved over 120 times consecutively
        if num_streaks > STREAK_TO_END:
            break

        # Update parameters
        explore_rate = get_explore_rate(episode)
        learning_rate = get_learning_rate(episode)
    Results.append(( S_timeSteps_list,S_TotalReward_list,S_Episodes_list ))
# Out:
# Episode 0 finished after 139.000000 time steps with total reward = 0.444000 (streak 0).
# Episode 1 finished after 203.000000 time steps with total reward = 0.188000 (streak 0).
# Episode 2 finished after 81.000000 time steps with total reward = 0.676000 (streak 0).
# Episode 3 finished after 73.000000 time steps with total reward = 0.708000 (streak 0).
# Episode 4 finished after 21.000000 time steps with total reward = 0.916000 (streak 0).
# Episode 5 finished after 43.000000 time steps with total reward = 0.828000 (streak 1).
# Episode 6 finished after 54.000000 time steps with total reward = 0.784000 (streak 0).
# Episode 7 finished after 9.000000 time steps with total reward = 0.964000 (streak 0).
# Episode 8 finished after 16.000000 time steps with total reward = 0.936000 (streak 1).
# Episode 9 finished after 9.000000 time steps with total reward = 0.964000 (streak 2).
# Episode 10 finished after 11.000000 time steps with total reward = 0.956000 (streak 3).
# Episode 11 finished after 68.000000 time steps with total reward = 0.728000 (streak 4).
# Episode 12 finished after 10.000000 time steps with total reward = 0.960000 (streak 0).
# Episode 13 finished after 18.000000 time steps with total reward = 0.928000 (streak 1).
# Episode 14 finished after 12.000000 time steps with total reward = 0.952000 (streak 2).
# Episode 15 finished after 8.000000 time steps with total reward = 0.968000 (streak 3).
# Episode 16 finished after 8.000000 time steps with total reward = 0.968000 (streak 4).
# Episode 17 finished after 13.000000 time steps with total reward = 0.948000 (streak 5).
# Episode 18 finished after 9.000000 time steps with total reward = 0.964000 (streak 6).
# Episode 19 finished after 8.000000 time steps with total reward = 0.968000 (streak 7).
# Episode 20 finished after 9.000000 time steps with total reward = 0.964000 (streak 8).
# Episode 21 finished after 9.000000 time steps with total reward = 0.964000 (streak 9).
# Episode 22 finished after 8.000000 time steps with total reward = 0.968000 (streak 10).
# Episode 23 finished after 8.000000 time steps with total reward = 0.968000 (streak 11).
# Episode 24 finished after 8.000000 time steps with total reward = 0.968000 (streak 12).
# Episode 25 finished after 8.000000 time steps with total reward = 0.968000 (streak 13).
# Episode 26 finished after 8.000000 time steps with total reward = 0.968000 (streak 14).
# Episode 27 finished after 8.000000 time steps with total reward = 0.968000 (streak 15).
# Episode 28 finished after 8.000000 time steps with total reward = 0.968000 (streak 16).
# Episode 29 finished after 8.000000 time steps with total reward = 0.968000 (streak 17).
# Episode 30 finished after 8.000000 time steps with total reward = 0.968000 (streak 18).
# Episode 31 finished after 8.000000 time steps with total reward = 0.968000 (streak 19).
# Episode 32 finished after 8.000000 time steps with total reward = 0.968000 (streak 20).
# Episode 33 finished after 8.000000 time steps with total reward = 0.968000 (streak 21).
# Episode 34 finished after 8.000000 time steps with total reward = 0.968000 (streak 22).
# Episode 35 finished after 8.000000 time steps with total reward = 0.968000 (streak 23).
# Episode 36 finished after 8.000000 time steps with total reward = 0.968000 (streak 24).
# Episode 37 finished after 8.000000 time steps with total reward = 0.968000 (streak 25).
# Episode 38 finished after 8.000000 time steps with total reward = 0.968000 (streak 26).
# Episode 39 finished after 8.000000 time steps with total reward = 0.968000 (streak 27).
# Episode 40 finished after 8.000000 time steps with total reward = 0.968000 (streak 28).
# Episode 41 finished after 8.000000 time steps with total reward = 0.968000 (streak 29).
# Episode 42 finished after 8.000000 time steps with total reward = 0.968000 (streak 30).
# Episode 43 finished after 8.000000 time steps with total reward = 0.968000 (streak 31).
# Episode 44 finished after 8.000000 time steps with total reward = 0.968000 (streak 32).
# Episode 45 finished after 8.000000 time steps with total reward = 0.968000 (streak 33).
# Episode 46 finished after 8.000000 time steps with total reward = 0.968000 (streak 34).
# Episode 47 finished after 8.000000 time steps with total reward = 0.968000 (streak 35).
# Episode 48 finished after 8.000000 time steps with total reward = 0.968000 (streak 36).
# Episode 49 finished after 8.000000 time steps with total reward = 0.968000 (streak 37).
# Episode 50 finished after 8.000000 time steps with total reward = 0.968000 (streak 38).
# Episode 51 finished after 8.000000 time steps with total reward = 0.968000 (streak 39).
# Episode 52 finished after 8.000000 time steps with total reward = 0.968000 (streak 40).
# Episode 53 finished after 8.000000 time steps with total reward = 0.968000 (streak 41).
# Episode 54 finished after 8.000000 time steps with total reward = 0.968000 (streak 42).
# Episode 55 finished after 8.000000 time steps with total reward = 0.968000 (streak 43).
# Episode 56 finished after 8.000000 time steps with total reward = 0.968000 (streak 44).
# Episode 57 finished after 8.000000 time steps with total reward = 0.968000 (streak 45).
# Episode 58 finished after 8.000000 time steps with total reward = 0.968000 (streak 46).
# Episode 59 finished after 8.000000 time steps with total reward = 0.968000 (streak 47).
# Episode 60 finished after 8.000000 time steps with total reward = 0.968000 (streak 48).
# Episode 61 finished after 8.000000 time steps with total reward = 0.968000 (streak 49).
# Episode 62 finished after 8.000000 time steps with total reward = 0.968000 (streak 50).
# Episode 63 finished after 8.000000 time steps with total reward = 0.968000 (streak 51).
# Episode 64 finished after 8.000000 time steps with total reward = 0.968000 (streak 52).
# Episode 65 finished after 8.000000 time steps with total reward = 0.968000 (streak 53).
# Episode 66 finished after 8.000000 time steps with total reward = 0.968000 (streak 54).
# Episode 67 finished after 8.000000 time steps with total reward = 0.968000 (streak 55).
# Episode 68 finished after 8.000000 time steps with total reward = 0.968000 (streak 56).
# Episode 69 finished after 8.000000 time steps with total reward = 0.968000 (streak 57).
# Episode 70 finished after 8.000000 time steps with total reward = 0.968000 (streak 58).
# Episode 71 finished after 8.000000 time steps with total reward = 0.968000 (streak 59).
# Episode 72 finished after 8.000000 time steps with total reward = 0.968000 (streak 60).
# Episode 73 finished after 8.000000 time steps with total reward = 0.968000 (streak 61).
# Episode 74 finished after 8.000000 time steps with total reward = 0.968000 (streak 62).
# Episode 75 finished after 8.000000 time steps with total reward = 0.968000 (streak 63).
# Episode 76 finished after 8.000000 time steps with total reward = 0.968000 (streak 64).
# Episode 77 finished after 8.000000 time steps with total reward = 0.968000 (streak 65).
# Episode 78 finished after 8.000000 time steps with total reward = 0.968000 (streak 66).
# Episode 79 finished after 8.000000 time steps with total reward = 0.968000 (streak 67).
# Episode 80 finished after 8.000000 time steps with total reward = 0.968000 (streak 68).
# Episode 81 finished after 8.000000 time steps with total reward = 0.968000 (streak 69).
# Episode 82 finished after 8.000000 time steps with total reward = 0.968000 (streak 70).
# Episode 83 finished after 8.000000 time steps with total reward = 0.968000 (streak 71).
# Episode 84 finished after 8.000000 time steps with total reward = 0.968000 (streak 72).
# Episode 85 finished after 8.000000 time steps with total reward = 0.968000 (streak 73).
# Episode 86 finished after 8.000000 time steps with total reward = 0.968000 (streak 74).
# Episode 87 finished after 8.000000 time steps with total reward = 0.968000 (streak 75).
# Episode 88 finished after 8.000000 time steps with total reward = 0.968000 (streak 76).
# Episode 89 finished after 8.000000 time steps with total reward = 0.968000 (streak 77).
# Episode 90 finished after 8.000000 time steps with total reward = 0.968000 (streak 78).
# Episode 91 finished after 8.000000 time steps with total reward = 0.968000 (streak 79).
# Episode 92 finished after 8.000000 time steps with total reward = 0.968000 (streak 80).
# Episode 93 finished after 8.000000 time steps with total reward = 0.968000 (streak 81).
# Episode 94 finished after 8.000000 time steps with total reward = 0.968000 (streak 82).
# Episode 95 finished after 8.000000 time steps with total reward = 0.968000 (streak 83).
# Episode 96 finished after 8.000000 time steps with total reward = 0.968000 (streak 84).
# Episode 97 finished after 8.000000 time steps with total reward = 0.968000 (streak 85).
# Episode 98 finished after 8.000000 time steps with total reward = 0.968000 (streak 86).
# Episode 99 finished after 8.000000 time steps with total reward = 0.968000 (streak 87).
# Episode 100 finished after 8.000000 time steps with total reward = 0.968000 (streak 88).
# Episode 101 finished after 8.000000 time steps with total reward = 0.968000 (streak 89).
# Episode 102 finished after 8.000000 time steps with total reward = 0.968000 (streak 90).
# Episode 103 finished after 8.000000 time steps with total reward = 0.968000 (streak 91).
# Episode 104 finished after 8.000000 time steps with total reward = 0.968000 (streak 92).
# Episode 105 finished after 8.000000 time steps with total reward = 0.968000 (streak 93).
# Episode 106 finished after 8.000000 time steps with total reward = 0.968000 (streak 94).
# Episode 107 finished after 8.000000 time steps with total reward = 0.968000 (streak 95).
# Episode 108 finished after 8.000000 time steps with total reward = 0.968000 (streak 96).
# Episode 109 finished after 8.000000 time steps with total reward = 0.968000 (streak 97).
# Episode 110 finished after 8.000000 time steps with total reward = 0.968000 (streak 98).
# Episode 111 finished after 8.000000 time steps with total reward = 0.968000 (streak 99).
# Episode 112 finished after 8.000000 time steps with total reward = 0.968000 (streak 100).
# Episode 0 finished after 343.000000 time steps with total reward = -0.372000 (streak 0).
# Episode 1 finished after 249.000000 time steps with total reward = 0.004000 (streak 0).
# Episode 2 finished after 292.000000 time steps with total reward = -0.168000 (streak 0).
# Episode 3 finished after 85.000000 time steps with total reward = 0.660000 (streak 0).
# Episode 4 finished after 224.000000 time steps with total reward = 0.104000 (streak 0).
# Episode 5 finished after 41.000000 time steps with total reward = 0.836000 (streak 0).
# Episode 6 finished after 29.000000 time steps with total reward = 0.884000 (streak 0).
# Episode 7 finished after 49.000000 time steps with total reward = 0.804000 (streak 0).
# Episode 8 finished after 22.000000 time steps with total reward = 0.912000 (streak 0).
# Episode 9 finished after 13.000000 time steps with total reward = 0.948000 (streak 1).
# Episode 10 finished after 11.000000 time steps with total reward = 0.956000 (streak 2).
# Episode 11 finished after 14.000000 time steps with total reward = 0.944000 (streak 3).
# Episode 12 finished after 14.000000 time steps with total reward = 0.944000 (streak 4).
# Episode 13 finished after 25.000000 time steps with total reward = 0.900000 (streak 5).
# Episode 14 finished after 9.000000 time steps with total reward = 0.964000 (streak 6).
# Episode 15 finished after 9.000000 time steps with total reward = 0.964000 (streak 7).
# Episode 16 finished after 13.000000 time steps with total reward = 0.948000 (streak 8).
# Episode 17 finished after 10.000000 time steps with total reward = 0.960000 (streak 9).
# Episode 18 finished after 9.000000 time steps with total reward = 0.964000 (streak 10).
# Episode 19 finished after 12.000000 time steps with total reward = 0.952000 (streak 11).
# Episode 20 finished after 13.000000 time steps with total reward = 0.948000 (streak 12).
# Episode 21 finished after 9.000000 time steps with total reward = 0.964000 (streak 13).
# Episode 22 finished after 9.000000 time steps with total reward = 0.964000 (streak 14).
# Episode 23 finished after 9.000000 time steps with total reward = 0.964000 (streak 15).
# Episode 24 finished after 9.000000 time steps with total reward = 0.964000 (streak 16).
# Episode 25 finished after 9.000000 time steps with total reward = 0.964000 (streak 17).
# Episode 26 finished after 9.000000 time steps with total reward = 0.964000 (streak 18).
# Episode 27 finished after 9.000000 time steps with total reward = 0.964000 (streak 19).
# Episode 28 finished after 9.000000 time steps with total reward = 0.964000 (streak 20).
# Episode 29 finished after 9.000000 time steps with total reward = 0.964000 (streak 21).
# Episode 30 finished after 9.000000 time steps with total reward = 0.964000 (streak 22).
# Episode 31 finished after 9.000000 time steps with total reward = 0.964000 (streak 23).
# Episode 32 finished after 9.000000 time steps with total reward = 0.964000 (streak 24).
# Episode 33 finished after 9.000000 time steps with total reward = 0.964000 (streak 25).
# Episode 34 finished after 9.000000 time steps with total reward = 0.964000 (streak 26).
# Episode 35 finished after 9.000000 time steps with total reward = 0.964000 (streak 27).
# Episode 36 finished after 9.000000 time steps with total reward = 0.964000 (streak 28).
# Episode 37 finished after 9.000000 time steps with total reward = 0.964000 (streak 29).
# Episode 38 finished after 9.000000 time steps with total reward = 0.964000 (streak 30).
# Episode 39 finished after 9.000000 time steps with total reward = 0.964000 (streak 31).
# Episode 40 finished after 9.000000 time steps with total reward = 0.964000 (streak 32).
# Episode 41 finished after 11.000000 time steps with total reward = 0.956000 (streak 33).
# Episode 42 finished after 9.000000 time steps with total reward = 0.964000 (streak 34).
# Episode 43 finished after 9.000000 time steps with total reward = 0.964000 (streak 35).
# Episode 44 finished after 9.000000 time steps with total reward = 0.964000 (streak 36).
# Episode 45 finished after 9.000000 time steps with total reward = 0.964000 (streak 37).
# Episode 46 finished after 9.000000 time steps with total reward = 0.964000 (streak 38).
# Episode 47 finished after 9.000000 time steps with total reward = 0.964000 (streak 39).
# Episode 48 finished after 9.000000 time steps with total reward = 0.964000 (streak 40).
# Episode 49 finished after 9.000000 time steps with total reward = 0.964000 (streak 41).
# Episode 50 finished after 9.000000 time steps with total reward = 0.964000 (streak 42).
# Episode 51 finished after 9.000000 time steps with total reward = 0.964000 (streak 43).
# Episode 52 finished after 9.000000 time steps with total reward = 0.964000 (streak 44).
# Episode 53 finished after 9.000000 time steps with total reward = 0.964000 (streak 45).
# Episode 54 finished after 9.000000 time steps with total reward = 0.964000 (streak 46).
# Episode 55 finished after 9.000000 time steps with total reward = 0.964000 (streak 47).
# Episode 56 finished after 9.000000 time steps with total reward = 0.964000 (streak 48).
# Episode 57 finished after 9.000000 time steps with total reward = 0.964000 (streak 49).
# Episode 58 finished after 9.000000 time steps with total reward = 0.964000 (streak 50).
# Episode 59 finished after 9.000000 time steps with total reward = 0.964000 (streak 51).
# Episode 60 finished after 9.000000 time steps with total reward = 0.964000 (streak 52).
# Episode 61 finished after 9.000000 time steps with total reward = 0.964000 (streak 53).
# Episode 62 finished after 9.000000 time steps with total reward = 0.964000 (streak 54).
# Episode 63 finished after 9.000000 time steps with total reward = 0.964000 (streak 55).
# Episode 64 finished after 13.000000 time steps with total reward = 0.948000 (streak 56).
# Episode 65 finished after 9.000000 time steps with total reward = 0.964000 (streak 57).
# Episode 66 finished after 9.000000 time steps with total reward = 0.964000 (streak 58).
# Episode 67 finished after 9.000000 time steps with total reward = 0.964000 (streak 59).
# Episode 68 finished after 9.000000 time steps with total reward = 0.964000 (streak 60).
# Episode 69 finished after 9.000000 time steps with total reward = 0.964000 (streak 61).
# Episode 70 finished after 9.000000 time steps with total reward = 0.964000 (streak 62).
# Episode 71 finished after 9.000000 time steps with total reward = 0.964000 (streak 63).
# Episode 72 finished after 9.000000 time steps with total reward = 0.964000 (streak 64).
# Episode 73 finished after 9.000000 time steps with total reward = 0.964000 (streak 65).
# Episode 74 finished after 9.000000 time steps with total reward = 0.964000 (streak 66).
# Episode 75 finished after 9.000000 time steps with total reward = 0.964000 (streak 67).
# Episode 76 finished after 9.000000 time steps with total reward = 0.964000 (streak 68).
# Episode 77 finished after 9.000000 time steps with total reward = 0.964000 (streak 69).
# Episode 78 finished after 9.000000 time steps with total reward = 0.964000 (streak 70).
# Episode 79 finished after 9.000000 time steps with total reward = 0.964000 (streak 71).
# Episode 80 finished after 9.000000 time steps with total reward = 0.964000 (streak 72).
# Episode 81 finished after 9.000000 time steps with total reward = 0.964000 (streak 73).
# Episode 82 finished after 9.000000 time steps with total reward = 0.964000 (streak 74).
# Episode 83 finished after 9.000000 time steps with total reward = 0.964000 (streak 75).
# Episode 84 finished after 9.000000 time steps with total reward = 0.964000 (streak 76).
# Episode 85 finished after 9.000000 time steps with total reward = 0.964000 (streak 77).
# Episode 86 finished after 9.000000 time steps with total reward = 0.964000 (streak 78).
# Episode 87 finished after 9.000000 time steps with total reward = 0.964000 (streak 79).
# Episode 88 finished after 9.000000 time steps with total reward = 0.964000 (streak 80).
# Episode 89 finished after 9.000000 time steps with total reward = 0.964000 (streak 81).
# Episode 90 finished after 9.000000 time steps with total reward = 0.964000 (streak 82).
# Episode 91 finished after 9.000000 time steps with total reward = 0.964000 (streak 83).
# Episode 92 finished after 9.000000 time steps with total reward = 0.964000 (streak 84).
# Episode 93 finished after 9.000000 time steps with total reward = 0.964000 (streak 85).
# Episode 94 finished after 9.000000 time steps with total reward = 0.964000 (streak 86).
# Episode 95 finished after 9.000000 time steps with total reward = 0.964000 (streak 87).
# Episode 96 finished after 9.000000 time steps with total reward = 0.964000 (streak 88).
# Episode 97 finished after 9.000000 time steps with total reward = 0.964000 (streak 89).
# Episode 98 finished after 9.000000 time steps with total reward = 0.964000 (streak 90).
# Episode 99 finished after 9.000000 time steps with total reward = 0.964000 (streak 91).
# Episode 100 finished after 9.000000 time steps with total reward = 0.964000 (streak 92).
# Episode 101 finished after 9.000000 time steps with total reward = 0.964000 (streak 93).
# Episode 102 finished after 9.000000 time steps with total reward = 0.964000 (streak 94).
# Episode 103 finished after 9.000000 time steps with total reward = 0.964000 (streak 95).
# Episode 104 finished after 9.000000 time steps with total reward = 0.964000 (streak 96).
# Episode 105 finished after 9.000000 time steps with total reward = 0.964000 (streak 97).
# Episode 106 finished after 9.000000 time steps with total reward = 0.964000 (streak 98).
# Episode 107 finished after 8.000000 time steps with total reward = 0.968000 (streak 99).
# Episode 108 finished after 9.000000 time steps with total reward = 0.964000 (streak 100).
# Episode 0 finished after 186.000000 time steps with total reward = 0.256000 (streak 0).
# Episode 1 finished after 190.000000 time steps with total reward = 0.240000 (streak 0).
# Episode 2 finished after 67.000000 time steps with total reward = 0.732000 (streak 0).
# Episode 3 finished after 179.000000 time steps with total reward = 0.284000 (streak 0).
# Episode 4 finished after 107.000000 time steps with total reward = 0.572000 (streak 0).
# Episode 5 finished after 20.000000 time steps with total reward = 0.920000 (streak 0).
# Episode 6 finished after 49.000000 time steps with total reward = 0.804000 (streak 1).
# Episode 7 finished after 57.000000 time steps with total reward = 0.772000 (streak 0).
# Episode 8 finished after 39.000000 time steps with total reward = 0.844000 (streak 0).
# Episode 9 finished after 25.000000 time steps with total reward = 0.900000 (streak 0).
# Episode 10 finished after 13.000000 time steps with total reward = 0.948000 (streak 1).
# Episode 11 finished after 7.000000 time steps with total reward = 0.972000 (streak 2).
# Episode 12 finished after 9.000000 time steps with total reward = 0.964000 (streak 3).
# Episode 13 finished after 10.000000 time steps with total reward = 0.960000 (streak 4).
# Episode 14 finished after 10.000000 time steps with total reward = 0.960000 (streak 5).
# Episode 15 finished after 7.000000 time steps with total reward = 0.972000 (streak 6).
# Episode 16 finished after 7.000000 time steps with total reward = 0.972000 (streak 7).
# Episode 17 finished after 9.000000 time steps with total reward = 0.964000 (streak 8).
# Episode 18 finished after 7.000000 time steps with total reward = 0.972000 (streak 9).
# Episode 19 finished after 10.000000 time steps with total reward = 0.960000 (streak 10).
# Episode 20 finished after 7.000000 time steps with total reward = 0.972000 (streak 11).
# Episode 21 finished after 7.000000 time steps with total reward = 0.972000 (streak 12).
# Episode 22 finished after 7.000000 time steps with total reward = 0.972000 (streak 13).
# Episode 23 finished after 7.000000 time steps with total reward = 0.972000 (streak 14).
# Episode 24 finished after 7.000000 time steps with total reward = 0.972000 (streak 15).
# Episode 25 finished after 7.000000 time steps with total reward = 0.972000 (streak 16).
# Episode 26 finished after 7.000000 time steps with total reward = 0.972000 (streak 17).
# Episode 27 finished after 7.000000 time steps with total reward = 0.972000 (streak 18).
# Episode 28 finished after 7.000000 time steps with total reward = 0.972000 (streak 19).
# Episode 29 finished after 7.000000 time steps with total reward = 0.972000 (streak 20).
# Episode 30 finished after 7.000000 time steps with total reward = 0.972000 (streak 21).
# Episode 31 finished after 7.000000 time steps with total reward = 0.972000 (streak 22).
# Episode 32 finished after 7.000000 time steps with total reward = 0.972000 (streak 23).
# Episode 33 finished after 7.000000 time steps with total reward = 0.972000 (streak 24).
# Episode 34 finished after 7.000000 time steps with total reward = 0.972000 (streak 25).
# Episode 35 finished after 7.000000 time steps with total reward = 0.972000 (streak 26).
# Episode 36 finished after 7.000000 time steps with total reward = 0.972000 (streak 27).
# Episode 37 finished after 7.000000 time steps with total reward = 0.972000 (streak 28).
# Episode 38 finished after 7.000000 time steps with total reward = 0.972000 (streak 29).
# Episode 39 finished after 7.000000 time steps with total reward = 0.972000 (streak 30).
# Episode 40 finished after 7.000000 time steps with total reward = 0.972000 (streak 31).
# Episode 41 finished after 7.000000 time steps with total reward = 0.972000 (streak 32).
# Episode 42 finished after 7.000000 time steps with total reward = 0.972000 (streak 33).
# Episode 43 finished after 7.000000 time steps with total reward = 0.972000 (streak 34).
# Episode 44 finished after 7.000000 time steps with total reward = 0.972000 (streak 35).
# Episode 45 finished after 7.000000 time steps with total reward = 0.972000 (streak 36).
# Episode 46 finished after 7.000000 time steps with total reward = 0.972000 (streak 37).
# Episode 47 finished after 7.000000 time steps with total reward = 0.972000 (streak 38).
# Episode 48 finished after 7.000000 time steps with total reward = 0.972000 (streak 39).
# Episode 49 finished after 7.000000 time steps with total reward = 0.972000 (streak 40).
# Episode 50 finished after 7.000000 time steps with total reward = 0.972000 (streak 41).
# Episode 51 finished after 7.000000 time steps with total reward = 0.972000 (streak 42).
# Episode 52 finished after 7.000000 time steps with total reward = 0.972000 (streak 43).
# Episode 53 finished after 7.000000 time steps with total reward = 0.972000 (streak 44).
# Episode 54 finished after 7.000000 time steps with total reward = 0.972000 (streak 45).
# Episode 55 finished after 7.000000 time steps with total reward = 0.972000 (streak 46).
# Episode 56 finished after 7.000000 time steps with total reward = 0.972000 (streak 47).
# Episode 57 finished after 7.000000 time steps with total reward = 0.972000 (streak 48).
# Episode 58 finished after 7.000000 time steps with total reward = 0.972000 (streak 49).
# Episode 59 finished after 8.000000 time steps with total reward = 0.968000 (streak 50).
# Episode 60 finished after 69.000000 time steps with total reward = 0.724000 (streak 51).
# Episode 61 finished after 7.000000 time steps with total reward = 0.972000 (streak 0).
# Episode 62 finished after 7.000000 time steps with total reward = 0.972000 (streak 1).
# Episode 63 finished after 7.000000 time steps with total reward = 0.972000 (streak 2).
# Episode 64 finished after 7.000000 time steps with total reward = 0.972000 (streak 3).
# Episode 65 finished after 7.000000 time steps with total reward = 0.972000 (streak 4).
# Episode 66 finished after 7.000000 time steps with total reward = 0.972000 (streak 5).
# Episode 67 finished after 7.000000 time steps with total reward = 0.972000 (streak 6).
# Episode 68 finished after 7.000000 time steps with total reward = 0.972000 (streak 7).
# Episode 69 finished after 7.000000 time steps with total reward = 0.972000 (streak 8).
# Episode 70 finished after 7.000000 time steps with total reward = 0.972000 (streak 9).
# Episode 71 finished after 7.000000 time steps with total reward = 0.972000 (streak 10).
# Episode 72 finished after 7.000000 time steps with total reward = 0.972000 (streak 11).
# Episode 73 finished after 7.000000 time steps with total reward = 0.972000 (streak 12).
# Episode 74 finished after 7.000000 time steps with total reward = 0.972000 (streak 13).
# Episode 75 finished after 7.000000 time steps with total reward = 0.972000 (streak 14).
# Episode 76 finished after 7.000000 time steps with total reward = 0.972000 (streak 15).
# Episode 77 finished after 7.000000 time steps with total reward = 0.972000 (streak 16).
# Episode 78 finished after 7.000000 time steps with total reward = 0.972000 (streak 17).
# Episode 79 finished after 7.000000 time steps with total reward = 0.972000 (streak 18).
# Episode 80 finished after 7.000000 time steps with total reward = 0.972000 (streak 19).
# Episode 81 finished after 7.000000 time steps with total reward = 0.972000 (streak 20).
# Episode 82 finished after 7.000000 time steps with total reward = 0.972000 (streak 21).
# Episode 83 finished after 7.000000 time steps with total reward = 0.972000 (streak 22).
# Episode 84 finished after 7.000000 time steps with total reward = 0.972000 (streak 23).
# Episode 85 finished after 7.000000 time steps with total reward = 0.972000 (streak 24).
# Episode 86 finished after 7.000000 time steps with total reward = 0.972000 (streak 25).
# Episode 87 finished after 7.000000 time steps with total reward = 0.972000 (streak 26).
# Episode 88 finished after 7.000000 time steps with total reward = 0.972000 (streak 27).
# Episode 89 finished after 7.000000 time steps with total reward = 0.972000 (streak 28).
# Episode 90 finished after 7.000000 time steps with total reward = 0.972000 (streak 29).
# Episode 91 finished after 7.000000 time steps with total reward = 0.972000 (streak 30).
# Episode 92 finished after 7.000000 time steps with total reward = 0.972000 (streak 31).
# Episode 93 finished after 7.000000 time steps with total reward = 0.972000 (streak 32).
# Episode 94 finished after 7.000000 time steps with total reward = 0.972000 (streak 33).
# Episode 95 finished after 7.000000 time steps with total reward = 0.972000 (streak 34).
# Episode 96 finished after 7.000000 time steps with total reward = 0.972000 (streak 35).
# Episode 97 finished after 7.000000 time steps with total reward = 0.972000 (streak 36).
# Episode 98 finished after 7.000000 time steps with total reward = 0.972000 (streak 37).
# Episode 99 finished after 7.000000 time steps with total reward = 0.972000 (streak 38).
# Episode 100 finished after 7.000000 time steps with total reward = 0.972000 (streak 39).
# Episode 101 finished after 7.000000 time steps with total reward = 0.972000 (streak 40).
# Episode 102 finished after 7.000000 time steps with total reward = 0.972000 (streak 41).
# Episode 103 finished after 7.000000 time steps with total reward = 0.972000 (streak 42).
# Episode 104 finished after 7.000000 time steps with total reward = 0.972000 (streak 43).
# Episode 105 finished after 7.000000 time steps with total reward = 0.972000 (streak 44).
# Episode 106 finished after 7.000000 time steps with total reward = 0.972000 (streak 45).
# Episode 107 finished after 7.000000 time steps with total reward = 0.972000 (streak 46).
# Episode 108 finished after 7.000000 time steps with total reward = 0.972000 (streak 47).
# Episode 109 finished after 7.000000 time steps with total reward = 0.972000 (streak 48).
# Episode 110 finished after 7.000000 time steps with total reward = 0.972000 (streak 49).
# Episode 111 finished after 7.000000 time steps with total reward = 0.972000 (streak 50).
# Episode 112 finished after 7.000000 time steps with total reward = 0.972000 (streak 51).
# Episode 113 finished after 7.000000 time steps with total reward = 0.972000 (streak 52).
# Episode 114 finished after 7.000000 time steps with total reward = 0.972000 (streak 53).
# Episode 115 finished after 7.000000 time steps with total reward = 0.972000 (streak 54).
# Episode 116 finished after 7.000000 time steps with total reward = 0.972000 (streak 55).
# Episode 117 finished after 7.000000 time steps with total reward = 0.972000 (streak 56).
# Episode 118 finished after 7.000000 time steps with total reward = 0.972000 (streak 57).
# Episode 119 finished after 7.000000 time steps with total reward = 0.972000 (streak 58).
# Episode 120 finished after 7.000000 time steps with total reward = 0.972000 (streak 59).
# Episode 121 finished after 7.000000 time steps with total reward = 0.972000 (streak 60).
# Episode 122 finished after 7.000000 time steps with total reward = 0.972000 (streak 61).
# Episode 123 finished after 7.000000 time steps with total reward = 0.972000 (streak 62).
# Episode 124 finished after 7.000000 time steps with total reward = 0.972000 (streak 63).
# Episode 125 finished after 7.000000 time steps with total reward = 0.972000 (streak 64).
# Episode 126 finished after 7.000000 time steps with total reward = 0.972000 (streak 65).
# Episode 127 finished after 7.000000 time steps with total reward = 0.972000 (streak 66).
# Episode 128 finished after 7.000000 time steps with total reward = 0.972000 (streak 67).
# Episode 129 finished after 7.000000 time steps with total reward = 0.972000 (streak 68).
# Episode 130 finished after 7.000000 time steps with total reward = 0.972000 (streak 69).
# Episode 131 finished after 7.000000 time steps with total reward = 0.972000 (streak 70).
# Episode 132 finished after 7.000000 time steps with total reward = 0.972000 (streak 71).
# Episode 133 finished after 7.000000 time steps with total reward = 0.972000 (streak 72).
# Episode 134 finished after 7.000000 time steps with total reward = 0.972000 (streak 73).
# Episode 135 finished after 7.000000 time steps with total reward = 0.972000 (streak 74).
# Episode 136 finished after 7.000000 time steps with total reward = 0.972000 (streak 75).
# Episode 137 finished after 7.000000 time steps with total reward = 0.972000 (streak 76).
# Episode 138 finished after 7.000000 time steps with total reward = 0.972000 (streak 77).
# Episode 139 finished after 7.000000 time steps with total reward = 0.972000 (streak 78).
# Episode 140 finished after 7.000000 time steps with total reward = 0.972000 (streak 79).
# Episode 141 finished after 7.000000 time steps with total reward = 0.972000 (streak 80).
# Episode 142 finished after 7.000000 time steps with total reward = 0.972000 (streak 81).
# Episode 143 finished after 7.000000 time steps with total reward = 0.972000 (streak 82).
# Episode 144 finished after 7.000000 time steps with total reward = 0.972000 (streak 83).
# Episode 145 finished after 7.000000 time steps with total reward = 0.972000 (streak 84).
# Episode 146 finished after 7.000000 time steps with total reward = 0.972000 (streak 85).
# Episode 147 finished after 7.000000 time steps with total reward = 0.972000 (streak 86).
# Episode 148 finished after 7.000000 time steps with total reward = 0.972000 (streak 87).
# Episode 149 finished after 7.000000 time steps with total reward = 0.972000 (streak 88).
# Episode 150 finished after 7.000000 time steps with total reward = 0.972000 (streak 89).
# Episode 151 finished after 7.000000 time steps with total reward = 0.972000 (streak 90).
# Episode 152 finished after 7.000000 time steps with total reward = 0.972000 (streak 91).
# Episode 153 finished after 7.000000 time steps with total reward = 0.972000 (streak 92).
# Episode 154 finished after 7.000000 time steps with total reward = 0.972000 (streak 93).
# Episode 155 finished after 7.000000 time steps with total reward = 0.972000 (streak 94).
# Episode 156 finished after 7.000000 time steps with total reward = 0.972000 (streak 95).
# Episode 157 finished after 7.000000 time steps with total reward = 0.972000 (streak 96).
# Episode 158 finished after 7.000000 time steps with total reward = 0.972000 (streak 97).
# Episode 159 finished after 8.000000 time steps with total reward = 0.968000 (streak 98).
# Episode 160 finished after 7.000000 time steps with total reward = 0.972000 (streak 99).
# Episode 161 finished after 7.000000 time steps with total reward = 0.972000 (streak 100).

# %%
#saving results
titles = ['Close','Mid','Far']
path = "data/SARSA/Portals/"
# path = "data/SARSA/NoPortals/"
i=0
for tuple_ in Results:
    #save into files
    if not os.path.exists(path):
        os.makedirs(path)
    np.save(path+f"{titles[i]}",tuple_)
    i+=1

# %% [markdown]
# # DQN

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
class Replay(object):
    #memory for training the DQN
    def __init__(self):
        self.max_size = 100
        self.transitions = []  # (old state, new state, action, reward)

    def store(self, s0, s, a, r):
        self.transitions.append((s0, s, a, r))
        if len(self.transitions) > self.max_size:
            self.transitions.pop(0)

    def sample(self):
        return self.transitions[random.randint(0, len(self.transitions) - 1)]


class DQN(nn.Module):
    def __init__(self):
        super(DQN, self).__init__()
        self.layer1 = nn.LSTM(2, 4, num_layers=32)
        self.layer2 = nn.LSTM(4, 8, num_layers=64)
        self.layer3 = nn.LSTM(8, 16, num_layers=64)
        self.relu = nn.ReLU()
        self.fc = nn.Linear(16, 4)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x, h = self.layer1(x)
        x=self.relu(x)
        x,h=self.layer2(x)
        x=self.relu(x)
        x,h=self.layer3(x)
        x = self.relu(x)
        x = self.fc(x)
        # x = self.sigmoid(x)
        return x

    def test(self):
        pass

    def select_action(self, state, er, device):
        # Select a random action
        if random.random() < er:
            action = env.action_space.sample()
        # Select the action with the highest q
        else:
            with torch.no_grad():
                state = torch.FloatTensor([state[0], state[1]]).view(1, 1, len(state)).to(device)
                val, action = self.forward(state)[0][0].max(0)
                action = action.item()
        return action

# %%
# Instantiating the learning related parameters
discount_factor = 0.99
update_target = 5

num_streaks = 0

# Render the maze
env.render()
dqn = DQN()
device = torch.device('cpu')
dqn = dqn.to(device)
target = DQN()
target = target.to(device)
dqn_opt = optim.Adam(dqn.parameters())
dqn_opt.zero_grad()
replay = Replay()
loss = nn.MSELoss()

for episode in range(NUM_EPISODES):
    # Reset the environment
    obv = env.reset()

    # the initial state
    s0 = state_to_bucket(obv)
    total_reward = 0
    total_loss = 0

    # Update parameters
    explore_rate = get_explore_rate(episode)
    learning_rate = get_learning_rate(episode)

    for t in range(MAX_T):
        # Select an action
        action = dqn.select_action(s0, explore_rate, device)

        # execute the action
        obv, reward, done, _ = env.step(action)

        # Observe the result
        s = state_to_bucket(obv)
        total_reward += reward

        # store the transition
        replay.store(s0, s, action, reward)

        # update the dqn
        r_s0, r_s, r_a, r_r = replay.sample()
        r_s0 = torch.FloatTensor([r_s0[0], r_s0[1]]).view(1, 1, len(r_s0)).to(device)
        r_s = torch.FloatTensor([r_s[0], r_s[1]]).view(1, 1, len(r_s)).to(device)
        dqn_output =dqn.forward(r_s0)
        target_output=target.forward(r_s)
        dqn_opt.zero_grad()
        l = loss(dqn_output, target_output)
        l.backward()
        dqn_opt.step()
        total_loss+=l.item()

        # update the target network
        if episode % update_target == 0:
            target.load_state_dict(dqn.state_dict())

        # Setting up for the next iteration
        s0 = s

        # Render tha maze
        if RENDER_MAZE:
            env.render()

        if env.is_game_over():
            sys.exit()

        if done:
            print("Episode %d finished after %f time steps with total reward = %f, loss = %f (streak %d)."
                  % (episode, t, total_reward, total_loss, num_streaks))

            if t <= SOLVED_T:
                num_streaks += 1
            else:
                num_streaks = 0
            break

        elif t >= MAX_T - 1:
            print("Episode %d timed out at %d with total reward = %f."
                  % (episode, t, total_reward))

    # It's considered done when it's solved over 120 times consecutively
    if num_streaks > STREAK_TO_END:
        break
